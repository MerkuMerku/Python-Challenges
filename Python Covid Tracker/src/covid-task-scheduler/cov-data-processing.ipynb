# %% [markdown]
# ## Imports

# %%
import os
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from sqlalchemy import create_engine
from matplotlib import pyplot as plt
from datetime import datetime

#turn off annoying warnigns
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Function 1: Data Collection

# %%
url = "https://www.worldometers.info/coronavirus/"
htmlContent = requests.get(url).text

soup = BeautifulSoup(htmlContent, 'html.parser')
covidTable = soup.find("table",attrs={"id": "main_table_countries_today"})

# %% [markdown]
# ## Function 2: Main Data Extract

# %%
# extract the table headings from the soup
head = covidTable.thead.find_all("tr")
headings = []

for th in head[0].find_all("th"):
    headings.append(th.text.replace("\n", "").strip())

# extract actual data from the soup
body = covidTable.tbody.find_all("tr")
data = []

# iterate through every row in the html
for r in range(1,len(body)):
    row = []
    # find all column entries in that particular row
    for tr in body[r].find_all("td"):
        row.append(tr.text.replace("\n","").strip())
    len(row)
    data.append(row)

df = pd.DataFrame(data,columns = headings)
df.head(20)

######################################################################
#                         CLEAN DATA TABLE                           #
######################################################################

# define nan object
NaN = np.nan

# recover appropriate columns
df = df.filter(['Continent', 'Country,Other','TotalCases','TotalRecovered','Serious,Critical','ActiveCases','TotalDeaths']) 

# strip artefacts
df = df.replace(',','', regex=True)
df = df.replace('\+','', regex=True)
df = df.replace('', NaN, regex=True)

# convert appropriate columns to integer type
df[['TotalCases', 'TotalRecovered','Serious,Critical','ActiveCases','TotalDeaths']] = df[['TotalCases', 'TotalRecovered','Serious,Critical','ActiveCases','TotalDeaths']].apply(pd.to_numeric, downcast = 'float', errors = 'coerce')
df.head(20)

# add date of processing to all rows
now = datetime.now()
dt_string = now.strftime("%d%m%Y")
df['DateProcessed'] = dt_string
df
# Out:
#              Continent     Country,Other  TotalCases  TotalRecovered  \
# 0                 Asia              Asia  56239088.0      53562652.0
# 1        South America     South America  33167236.0      30143366.0
# 2               Europe            Europe  48164004.0      45537312.0
# 3               Africa            Africa   5642882.0       4898045.0
# 4    Australia/Oceania           Oceania     75830.0         69095.0
# ..                 ...               ...         ...             ...
# 224  Australia/Oceania  Marshall Islands         4.0             4.0
# 225  Australia/Oceania             Samoa         3.0             3.0
# 226             Africa      Saint Helena         2.0             2.0
# 227  Australia/Oceania        Micronesia         1.0             1.0
# 228               Asia             China     91833.0         86766.0
#
#      Serious,Critical  ActiveCases  TotalDeaths DateProcessed
# 0             26610.0    1878380.0     798055.0      03072021
# 1             29356.0    2011396.0    1012473.0      03072021
# 2              6549.0    1521138.0    1105553.0      03072021
# 3              4566.0     599938.0     144899.0      03072021
# 4                29.0       5449.0       1286.0      03072021
# ..                ...          ...          ...           ...
# 224               NaN          0.0          NaN      03072021
# 225               NaN          0.0          NaN      03072021
# 226               NaN          0.0          NaN      03072021
# 227               NaN          0.0          NaN      03072021
# 228               8.0        431.0       4636.0      03072021
#
# [229 rows x 8 columns]

# %% [markdown]
# ## Function 3: Extract Tables

# %%
############# world
world_df = df.loc[df['Country,Other'] == "World"]

# record worldwide cases
worldwideCases = world_df.iloc[0]['TotalCases']

# select our data for plotting:
world_df = world_df.filter(['TotalCases','TotalRecovered','Serious,Critical','ActiveCases','TotalDeaths', 'DateProcessed'])

# this is the correct way to add a new column from existing columns!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
world_df = world_df.assign(NonCritical_Active = float(world_df['ActiveCases']) - float(world_df['Serious,Critical']))
world_df.rename(columns = {'NonCritical_Active':'Non-Critical, Active', 'Serious,Critical':'Critical, Active'}, inplace = True)

# add in percentage columns
world_df = world_df.assign(TotalRecoveredPerc = (int(world_df['TotalRecovered']) / int(world_df['TotalCases'])) * 100)
world_df = world_df.assign(CritPerc = (int(world_df['Critical, Active']) / int(world_df['TotalCases'])) * 100)
world_df = world_df.assign(DeathPerc = (int(world_df['TotalDeaths']) / int(world_df['TotalCases'])) * 100)
world_df = world_df.assign(NonCritPerc = (int(world_df['Non-Critical, Active']) / int(world_df['TotalCases'])) * 100)

# drop redundant cols
world_df = world_df.drop(columns = ['ActiveCases']).reset_index(drop=True)

############ continent 
continents_df = df.iloc[0:5]
continents_df.drop(columns=['Country,Other'], inplace=True)

na = df.loc[df['Continent'] == "North America"]
del na["Continent"]

na = na.replace('','0', regex=True)

# create a row of data to append to the continents for North America
row = []
row.append("North America")

for column in na.columns[1:]:
    na[column] = pd.to_numeric(na[column], errors='coerce')
    row.append(round(na[column].sum()))
row = [row]

continents_df = continents_df.append(pd.DataFrame( row, columns=continents_df.columns), ignore_index = True)
continents_df = continents_df.sort_values(by=['TotalCases'], ascending=False)

############ country
countries_df = df.loc[7:len(df)]
countries_df = countries_df.reset_index()
countries_df = countries_df.drop(columns = ['index', 'Continent'])

# sort the data by total cases, as we did with continents:
countries_df = countries_df.sort_values(by=['TotalCases'],ascending=False)

# %% [markdown]
# ## Function 4: Create CSVs

# %%
# create a folder for the csv data extracts if there isn't aready one using the os module

path = os.getcwd()
directory = 'csv_extracts'

if os.path.isdir(directory):
    print("Extracts directory found at '%s'" % directory)
    path = os.path.join(path, directory)
    # for File in os.listdir('./csv_extracts'):
    #         os.remove(File)
    #         print("removed '%s'" % File)
else:
    print('Extracts directory not found, creating csv extracts directory and files...')
    path = os.path.join(path, directory)
    os.mkdir(path)
    if os.path.isdir(directory):
        print("Directory '% s' successfully created" % directory)
    else:
        print("Could not create directory '% s'" % directory)
        
# create csv files from extracts

# world df
csv_name = path + "/world_csv_" + dt_string + ".csv"
print(csv_name)
world_df.to_csv(csv_name)

# continents df
csv_name = path + "/continent_csv_" + dt_string + ".csv"
print(csv_name)
continents_df.to_csv(csv_name)

# countries df
csv_name = path + "/country_csv_" + dt_string + ".csv"
print(csv_name)
countries_df.to_csv(csv_name)
# Out:
# Extracts directory found at 'csv_extracts'
# /Users/markdunbar/Documents/Repositories/Python-Projects-and-Challenges/Python Covid Tracker/src/covid-task-scheduler/csv_extracts/world_csv_03072021.csv
# /Users/markdunbar/Documents/Repositories/Python-Projects-and-Challenges/Python Covid Tracker/src/covid-task-scheduler/csv_extracts/continent_csv_03072021.csv
# /Users/markdunbar/Documents/Repositories/Python-Projects-and-Challenges/Python Covid Tracker/src/covid-task-scheduler/csv_extracts/country_csv_03072021.csv

# %%
engine = create_engine('sqlite:///../application/site.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2021-07-03 15:29:39,724 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-07-03 15:29:39,744 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:29:39,746 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-07-03 15:29:39,749 INFO sqlalchemy.engine.base.Engine ()

# %%
world_df.to_sql("world", sqlite_connection, if_exists='replace')

continents_df.to_sql("continents", sqlite_connection, if_exists='replace')

countries_df.to_sql("countries", sqlite_connection, if_exists='replace')

sqlite_connection.close()
# Out:
# 2021-07-03 15:30:11,000 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("world")
# 2021-07-03 15:30:11,001 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,005 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("world")
# 2021-07-03 15:30:11,006 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,009 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-07-03 15:30:11,010 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,013 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_xinfo("world")
# 2021-07-03 15:30:11,015 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,021 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,022 INFO sqlalchemy.engine.base.Engine ('world',)
# 2021-07-03 15:30:11,023 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("world")
# 2021-07-03 15:30:11,026 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,029 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("world")
# 2021-07-03 15:30:11,031 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,034 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,035 INFO sqlalchemy.engine.base.Engine ('world',)
# 2021-07-03 15:30:11,036 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("world")
# 2021-07-03 15:30:11,038 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,039 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_world_index")
# 2021-07-03 15:30:11,040 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,044 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("world")
# 2021-07-03 15:30:11,047 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,049 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_world_index")
# 2021-07-03 15:30:11,050 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,052 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,052 INFO sqlalchemy.engine.base.Engine ('world',)
# 2021-07-03 15:30:11,054 INFO sqlalchemy.engine.base.Engine
# DROP TABLE world
# 2021-07-03 15:30:11,056 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,059 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,061 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE world (
# 	"index" BIGINT,
# 	"TotalCases" FLOAT,
# 	"TotalRecovered" FLOAT,
# 	"Critical, Active" FLOAT,
# 	"TotalDeaths" FLOAT,
# 	"DateProcessed" TEXT,
# 	"Non-Critical, Active" FLOAT,
# 	"TotalRecoveredPerc" FLOAT,
# 	"CritPerc" FLOAT,
# 	"DeathPerc" FLOAT,
# 	"NonCritPerc" FLOAT
# )
#
#
# 2021-07-03 15:30:11,064 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,069 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,073 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_world_index ON world ("index")
# 2021-07-03 15:30:11,075 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,079 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,082 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-07-03 15:30:11,085 INFO sqlalchemy.engine.base.Engine INSERT INTO world ("index", "TotalCases", "TotalRecovered", "Critical, Active", "TotalDeaths", "DateProcessed", "Non-Critical, Active", "TotalRecoveredPerc", "CritPerc", "DeathPerc", "NonCritPerc") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-07-03 15:30:11,087 INFO sqlalchemy.engine.base.Engine (0, 183979280.0, 168383760.0, 78037.0, 3982454.0, '03072021', 11535020.0, 91.52321935383159, 0.042416189475249604, 2.1646209290524454, 6.269738635785509)
# 2021-07-03 15:30:11,088 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,093 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("continents")
# 2021-07-03 15:30:11,094 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,095 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("continents")
# 2021-07-03 15:30:11,096 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,098 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-07-03 15:30:11,099 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,100 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_xinfo("continents")
# 2021-07-03 15:30:11,101 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,103 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,105 INFO sqlalchemy.engine.base.Engine ('continents',)
# 2021-07-03 15:30:11,106 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("continents")
# 2021-07-03 15:30:11,107 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,108 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("continents")
# 2021-07-03 15:30:11,108 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,109 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,110 INFO sqlalchemy.engine.base.Engine ('continents',)
# 2021-07-03 15:30:11,111 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("continents")
# 2021-07-03 15:30:11,111 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,112 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_continents_index")
# 2021-07-03 15:30:11,113 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,114 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("continents")
# 2021-07-03 15:30:11,115 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,116 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_continents_index")
# 2021-07-03 15:30:11,116 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,117 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,118 INFO sqlalchemy.engine.base.Engine ('continents',)
# 2021-07-03 15:30:11,119 INFO sqlalchemy.engine.base.Engine
# DROP TABLE continents
# 2021-07-03 15:30:11,120 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,123 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,126 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE continents (
# 	"index" BIGINT,
# 	"Continent" TEXT,
# 	"TotalCases" FLOAT,
# 	"TotalRecovered" FLOAT,
# 	"Serious,Critical" FLOAT,
# 	"ActiveCases" FLOAT,
# 	"TotalDeaths" FLOAT,
# 	"DateProcessed" TEXT
# )
#
#
# 2021-07-03 15:30:11,127 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,129 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,130 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_continents_index ON continents ("index")
# 2021-07-03 15:30:11,131 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,134 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,137 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-07-03 15:30:11,139 INFO sqlalchemy.engine.base.Engine INSERT INTO continents ("index", "Continent", "TotalCases", "TotalRecovered", "Serious,Critical", "ActiveCases", "TotalDeaths", "DateProcessed") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2021-07-03 15:30:11,140 INFO sqlalchemy.engine.base.Engine ((0, 'Asia', 56239088.0, 53562652.0, 26610.0, 1878380.0, 798055.0, '03072021'), (2, 'Europe', 48164004.0, 45537312.0, 6549.0, 1521138.0, 1105553.0, '03072021'), (5, 'North America', 40689508.0, 34172580.0, 10927.0, 5596756.0, 920173.0, 119808819), (1, 'South America', 33167236.0, 30143366.0, 29356.0, 2011396.0, 1012473.0, '03072021'), (3, 'Africa', 5642882.0, 4898045.0, 4566.0, 599938.0, 144899.0, '03072021'), (4, 'Australia/Oceania', 75830.0, 69095.0, 29.0, 5449.0, 1286.0, '03072021'))
# 2021-07-03 15:30:11,141 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,146 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("countries")
# 2021-07-03 15:30:11,147 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,149 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("countries")
# 2021-07-03 15:30:11,150 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,153 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-07-03 15:30:11,155 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,157 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_xinfo("countries")
# 2021-07-03 15:30:11,158 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,161 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,162 INFO sqlalchemy.engine.base.Engine ('countries',)
# 2021-07-03 15:30:11,164 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("countries")
# 2021-07-03 15:30:11,164 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,165 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("countries")
# 2021-07-03 15:30:11,166 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,168 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,169 INFO sqlalchemy.engine.base.Engine ('countries',)
# 2021-07-03 15:30:11,170 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("countries")
# 2021-07-03 15:30:11,171 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,172 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_countries_index")
# 2021-07-03 15:30:11,173 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,175 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("countries")
# 2021-07-03 15:30:11,176 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,177 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_countries_index")
# 2021-07-03 15:30:11,177 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,179 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-07-03 15:30:11,179 INFO sqlalchemy.engine.base.Engine ('countries',)
# 2021-07-03 15:30:11,181 INFO sqlalchemy.engine.base.Engine
# DROP TABLE countries
# 2021-07-03 15:30:11,182 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,187 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,189 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE countries (
# 	"index" BIGINT,
# 	"Country,Other" TEXT,
# 	"TotalCases" FLOAT,
# 	"TotalRecovered" FLOAT,
# 	"Serious,Critical" FLOAT,
# 	"ActiveCases" FLOAT,
# 	"TotalDeaths" FLOAT,
# 	"DateProcessed" TEXT
# )
#
#
# 2021-07-03 15:30:11,190 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,193 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,194 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_countries_index ON countries ("index")
# 2021-07-03 15:30:11,194 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-03 15:30:11,198 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-07-03 15:30:11,200 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-07-03 15:30:11,204 INFO sqlalchemy.engine.base.Engine INSERT INTO countries ("index", "Country,Other", "TotalCases", "TotalRecovered", "Serious,Critical", "ActiveCases", "TotalDeaths", "DateProcessed") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2021-07-03 15:30:11,206 INFO sqlalchemy.engine.base.Engine ((0, 'USA', 34580296.0, 29072892.0, 3867.0, 4886237.0, 621164.0, '03072021'), (1, 'India', 30514190.0, 29610908.0, 8944.0, 502063.0, 401218.0, '03072021'), (2, 'Brazil', 18687468.0, 16989352.0, 8318.0, 1176050.0, 522068.0, '03072021'), (3, 'France', 5780648.0, 5626675.0, 1123.0, 42838.0, 111135.0, '03072021'), (4, 'Russia', 5585799.0, 5053417.0, 2300.0, 395120.0, 137262.0, '03072021'), (5, 'Turkey', 5435831.0, 5305856.0, 697.0, 80146.0, 49829.0, '03072021'), (6, 'UK', 4855169.0, 4329769.0, 300.0, 397211.0, 128189.0, '03072021'), (7, 'Argentina', 4512439.0, 4114096.0, 5784.0, 302961.0, 95382.0, '03072021')  ... displaying 10 of 222 total bound parameter sets ...  (219, 'Saint Helena', 2.0, 2.0, None, 0.0, None, '03072021'), (220, 'Micronesia', 1.0, 1.0, None, 0.0, None, '03072021'))
# 2021-07-03 15:30:11,219 INFO sqlalchemy.engine.base.Engine COMMIT
